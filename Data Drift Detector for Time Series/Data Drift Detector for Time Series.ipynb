# %% [markdown]
# #  Data Drift Detector for Time Series
#
# Data evolves over time, causing a change in the distributions and interpretation. This is known as drift and causes a degradation in ML model performance. The Drift Detector detects changes in the incoming data, and provides useful insights to the user with respect to the data and model behavior. The solution can also trigger an alert for model retraining based on data drift detection results.

# %% [markdown]
# ## Contents
#
# 1. [Prequisites](#Prerequisite)
# 1. [Data Dictionary](#Data-Dictionary)
# 1. [Set Up The Environment](#Set-up-the-environment)
# 1. [Create The Model](#Create-Model)
# 1. [Batch Transform Job](#Batch-Transform-Job)
# 1. [Invoke Endpoint](#Invoking-through-Endpoint)

# %% [markdown]
# ### Prerequisites
#
# To run this algorithm you need to have access to the following AWS Services:
# - Access to AWS SageMaker and the model package.
# - An S3 bucket to specify input/output.
# - Role for AWS SageMaker to access input/output from S3.

# %% [markdown]
# ### Data Dictionary
#
# - The input has to be a '.csv' file with 'utf-8' encoding. PLEASE NOTE: If your input .csv file is not 'utf-8' encoded, model   will not perform as expected
# - The algorithm works with a time-series dataset with a row limit of not less than 100 instances.
# - Content type for input: The input must be in “.csv” format.
# - Input must contain columns ‘class’ and ‘predicted’.

# %% [markdown]
# ### Sample input data

# %%
import pandas as pd
df = pd.read_csv("prediction.csv")
pd.set_option('display.max_colwidth', -1)
df.head(10)
# Out:
#    Unnamed: 0  date  day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0  0           0.0   2    0.000000  0.056443  0.439155   0.003467  0.422915
# 1  1           0.0   2    0.021277  0.051699  0.415055   0.003467  0.422915
# 2  2           0.0   2    0.042553  0.051489  0.385004   0.003467  0.422915
# 3  3           0.0   2    0.063830  0.045485  0.314639   0.003467  0.422915
# 4  4           0.0   2    0.085106  0.042482  0.251116   0.003467  0.422915
# 5  5           0.0   2    0.106383  0.041161  0.207528   0.003467  0.422915
# 6  6           0.0   2    0.127660  0.041161  0.171824   0.003467  0.422915
# 7  7           0.0   2    0.148936  0.041161  0.152782   0.003467  0.422915
# 8  8           0.0   2    0.170213  0.041161  0.134930   0.003467  0.422915
# 9  9           0.0   2    0.191489  0.041161  0.140583   0.003467  0.422915
#
#    transfer class predicted
# 0  0.414912  UP    UP
# 1  0.414912  UP    UP
# 2  0.414912  UP    UP
# 3  0.414912  UP    UP
# 4  0.414912  DOWN  DOWN
# 5  0.414912  DOWN  DOWN
# 6  0.414912  DOWN  DOWN
# 7  0.414912  DOWN  DOWN
# 8  0.414912  DOWN  DOWN
# 9  0.414912  DOWN  DOWN

# %% [markdown]
# ### Create the session
#
# The session remembers our connection parameters to SageMaker. We'll use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage
from time import gmtime, strftime
from sagemaker import get_execution_role

sess = sage.Session()
role = get_execution_role()

# %% [markdown]
# ## Create Model
#
# Now we use the Model Package to create a model

# %%
# Please use the appropriate ARN obtained after subscribing to the model to define 'model_package_arn'

model_package_arn = 'arn:aws:sagemaker:us-east-2:786796469737:model-package/numerical-drift-v1'
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_session = sage.Session()
model = ModelPackage(model_package_arn=model_package_arn,
                    role = role,
                    sagemaker_session = sagemaker_session)

# %% [markdown]
# ## Input File
#
# Now we pull a sample input file for testing the model.

# %%
sample_txt="s3://aws-marketplace-mphasis-assets/marketplace-drift-numerical/prediction.csv"

# %% [markdown]
# ## Batch Transform Job
#
# Now let's use the model built to run a batch inference job and verify it works.

# %%
import json 
import uuid


transformer = model.transformer(1, 'ml.m5.xlarge')
transformer.transform(sample_txt, content_type='text/csv')
transformer.wait()
#transformer.output_path
print("Batch Transform complete")
# Out:
# ................. * Serving Flask app "serve" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:8080/ (Press CTRL+C to quit)
# 169.254.255.130 - - [30/Jun/2020 04:23:26] "#033GET /ping HTTP/1.1#033" 200 -
# 169.254.255.130 - - [30/Jun/2020 04:23:26] "#033GET /execution-parameters HTTP/1.1#033" 404 -
#        Unnamed: 0    date  day    period  ...  vicdemand  transfer  class  predicted
# 0               0  0.0000    2  0.000000  ...   0.422915  0.414912     UP         UP
# 1               1  0.0000    2  0.021277  ...   0.422915  0.414912     UP         UP
# 2               2  0.0000    2  0.042553  ...   0.422915  0.414912     UP         UP
# 3               3  0.0000    2  0.063830  ...   0.422915  0.414912     UP         UP
# 4               4  0.0000    2  0.085106  ...   0.422915  0.414912   DOWN       DOWN
# ...           ...     ...  ...       ...  ...        ...       ...    ...        ...
# 45307       45307  0.9158    7  0.914894  ...   0.255049  0.405263   DOWN         UP
# 45308       45308  0.9158    7  0.936170  ...   0.241326  0.420614   DOWN         UP
# 45309       45309  0.9158    7  0.957447  ...   0.247799  0.362281   DOWN         UP
# 45310       45310  0.9158    7  0.978723  ...   0.345417  0.206579     UP         UP
# 45311       45311  0.9158    7  1.000000  ...   0.355256  0.231140   DOWN         UP
#
# [45312 rows x 11 columns]
#            date day    period  nswprice  ...  vicdemand  transfer  class  predicted
# 223    0.000177   6  0.659574  0.072745  ...   0.422915  0.414912     UP         UP
# 255    0.000221   7  0.319149  0.047256  ...   0.422915  0.414912   DOWN         UP
# 287    0.000221   7  1.000000  0.047106  ...   0.422915  0.414912   DOWN         UP
# 415    0.000354   3  0.659574  0.045214  ...   0.422915  0.414912   DOWN         UP
# 1343   0.004248   1  1.000000  0.076108  ...   0.422915  0.414912     UP         UP
# 1375   0.004292   2  0.659574  0.046806  ...   0.422915  0.414912   DOWN         UP
# 1439   0.004336   3  1.000000  0.045394  ...   0.422915  0.414912   DOWN         UP
# 2207   0.005044   5  1.000000  0.047886  ...   0.422915  0.414912   DOWN         UP
# 2271   0.005133   7  0.319149  0.068362  ...   0.422915  0.414912     UP         UP
# 3807   0.009646   4  0.319149  0.045605  ...   0.422915  0.414912   DOWN         UP
# 4223   0.013053   5  1.000000  0.048247  ...   0.422915  0.414912     UP         UP
# 4511   0.013318   4  1.000000  0.081002  ...   0.422915  0.414912     UP         UP
# 4895   0.013672   5  1.000000  0.051549  ...   0.422915  0.414912     UP         UP
# 7871   0.022565   4  1.000000  0.057644  ...   0.422915  0.414912   DOWN         UP
# 8095   0.022787   2  0.659574  0.084814  ...   0.422915  0.414912   DOWN         UP
# 8447   0.023096   2  1.000000  0.101567  ...   0.422915  0.414912     UP         UP
# 10015  0.030707   7  0.659574  0.083794  ...   0.422915  0.414912     UP         UP
# 10111  0.030795   2  0.659574  0.111174  ...   0.422915  0.414912     UP         UP
# 11423  0.031990   1  1.000000  0.086015  ...   0.422915  0.414912     UP         UP
# 11679  0.424671   7  0.319149  0.074817  ...   0.422915  0.414912     UP         UP
# 15519  0.434450   3  0.319149  0.058094  ...   0.422915  0.414912     UP         UP
# 15615  0.434538   5  0.319149  0.044314  ...   0.422915  0.414912   DOWN         UP
# 21247  0.451971   3  0.659574  0.033626  ...   0.546349  0.385088   DOWN         UP
# 21343  0.452060   5  0.659574  0.033145  ...   0.555153  0.424561   DOWN         UP
# 21951  0.455688   4  0.319149  0.092110  ...   0.591921  0.492982     UP         UP
# 24735  0.464404   6  0.319149  0.037769  ...   0.431901  0.248246     UP         UP
# 24959  0.464581   3  1.000000  0.076048  ...   0.399534  0.351316     UP         UP
# 25247  0.477988   2  1.000000  0.038009  ...   0.385552  0.292982   DOWN         UP
# 25279  0.482412   3  0.659574  0.033746  ...   0.480321  0.217105   DOWN         UP
# 40031  0.898633   2  1.000000  0.078149  ...   0.496634  0.610088   DOWN         UP
# 41119  0.902703   4  0.659574  0.037829  ...   0.507509  0.390789   DOWN         UP
# 41279  0.902836   7  1.000000  0.048427  ...   0.404713  0.535526   DOWN         UP
# 43167  0.907703   5  0.319149  0.051339  ...   0.539617  0.397368     UP         UP
#
# [33 rows x 10 columns]
# 169.254.255.130 - - [30/Jun/2020 04:23:30] "#033POST /invocations HTTP/1.1#033" 200 -
# 2020-06-30T04:23:26.939:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# Batch Transform complete

# %% [markdown]
# ## Output from Batch Transform
#
# Note: Ensure that the following package is installed on the local system : boto3

# %%
import boto3
print(transformer.output_path)
bucketFolder = transformer.output_path.rsplit('/')[3]
bucket_name=transformer.output_path.rsplit('/')[2]

#print(s3bucket,s3prefix)
s3_conn = boto3.client("s3")
# bucket_name="sagemaker-us-east-2-786796469737"
with open('result.csv', 'wb') as f:
    s3_conn.download_fileobj(bucket_name,bucketFolder+'/prediction.csv.out', f)
    print("Output file loaded from bucket")
# Out:
# s3://sagemaker-us-east-2-786796469737/numerical-drift-v1-2020-06-30-04-20-23--2020-06-30-04-20-24-073
# Output file loaded from bucket

# %% [markdown]
# ## Result - Data points where drift has occurred

# %%
df = pd.read_csv("result.csv")
df=df.drop(columns='Unnamed: 0')
df
# Out:
#         date  day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0   0.000177  6    0.659574  0.072745  0.287266   0.003467  0.422915
# 1   0.000221  7    0.319149  0.047256  0.180452   0.003467  0.422915
# 2   0.000221  7    1.000000  0.047106  0.293663   0.003467  0.422915
# 3   0.000354  3    0.659574  0.045214  0.450164   0.003467  0.422915
# 4   0.004248  1    1.000000  0.076108  0.475156   0.003467  0.422915
# 5   0.004292  2    0.659574  0.046806  0.505653   0.003467  0.422915
# 6   0.004336  3    1.000000  0.045394  0.506397   0.003467  0.422915
# 7   0.005044  5    1.000000  0.047886  0.514281   0.003467  0.422915
# 8   0.005133  7    0.319149  0.068362  0.231627   0.003467  0.422915
# 9   0.009646  4    0.319149  0.045605  0.631508   0.003467  0.422915
# 10  0.013053  5    1.000000  0.048247  0.534216   0.003467  0.422915
# 11  0.013318  4    1.000000  0.081002  0.598483   0.003467  0.422915
# 12  0.013672  5    1.000000  0.051549  0.508331   0.003467  0.422915
# 13  0.022565  4    1.000000  0.057644  0.426807   0.003467  0.422915
# 14  0.022787  2    0.659574  0.084814  0.433502   0.003467  0.422915
# 15  0.023096  2    1.000000  0.101567  0.390955   0.003467  0.422915
# 16  0.030707  7    0.659574  0.083794  0.288158   0.003467  0.422915
# 17  0.030795  2    0.659574  0.111174  0.538976   0.003467  0.422915
# 18  0.031990  1    1.000000  0.086015  0.300208   0.003467  0.422915
# 19  0.424671  7    0.319149  0.074817  0.203957   0.003467  0.422915
# 20  0.434450  3    0.319149  0.058094  0.485272   0.003467  0.422915
# 21  0.434538  5    0.319149  0.044314  0.249331   0.003467  0.422915
# 22  0.451971  3    0.659574  0.033626  0.560994   0.002277  0.546349
# 23  0.452060  5    0.659574  0.033145  0.501041   0.002212  0.555153
# 24  0.455688  4    0.319149  0.092110  0.695031   0.006352  0.591921
# 25  0.464404  6    0.319149  0.037769  0.396906   0.002607  0.431901
# 26  0.464581  3    1.000000  0.076048  0.461619   0.005249  0.399534
# 27  0.477988  2    1.000000  0.038009  0.450759   0.002628  0.385552
# 28  0.482412  3    0.659574  0.033746  0.456858   0.002360  0.480321
# 29  0.898633  2    1.000000  0.078149  0.559357   0.005154  0.496634
# 30  0.902703  4    0.659574  0.037829  0.465933   0.002580  0.507509
# 31  0.902836  7    1.000000  0.048427  0.348706   0.003232  0.404713
# 32  0.907703  5    0.319149  0.051339  0.466677   0.003484  0.539617
#
#     transfer class predicted
# 0   0.414912  UP    UP
# 1   0.414912  DOWN  UP
# 2   0.414912  DOWN  UP
# 3   0.414912  DOWN  UP
# 4   0.414912  UP    UP
# 5   0.414912  DOWN  UP
# 6   0.414912  DOWN  UP
# 7   0.414912  DOWN  UP
# 8   0.414912  UP    UP
# 9   0.414912  DOWN  UP
# 10  0.414912  UP    UP
# 11  0.414912  UP    UP
# 12  0.414912  UP    UP
# 13  0.414912  DOWN  UP
# 14  0.414912  DOWN  UP
# 15  0.414912  UP    UP
# 16  0.414912  UP    UP
# 17  0.414912  UP    UP
# 18  0.414912  UP    UP
# 19  0.414912  UP    UP
# 20  0.414912  UP    UP
# 21  0.414912  DOWN  UP
# 22  0.385088  DOWN  UP
# 23  0.424561  DOWN  UP
# 24  0.492982  UP    UP
# 25  0.248246  UP    UP
# 26  0.351316  UP    UP
# 27  0.292982  DOWN  UP
# 28  0.217105  DOWN  UP
# 29  0.610088  DOWN  UP
# 30  0.390789  DOWN  UP
# 31  0.535526  DOWN  UP
# 32  0.397368  UP    UP

# %% [markdown]
# ## Invoking through Endpoint
# This is another way of deploying the model that provides results as real time inference. Here is a sample endpoint for reference

# %%
import json 
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
from sagemaker import ModelPackage
import boto3
from IPython.display import Image
from PIL import Image as ImageEdit

role = get_execution_role()

sagemaker_session = sage.Session()
bucket=sagemaker_session.default_bucket()

# %%
content_type='text/csv'
model_name='drift-detector'
real_time_inference_instance_type='ml.c4.2xlarge'

# %%
# Please use the appropriate ARN obtained after subscribing to the model to define 'model_package_arn'
model_package_arn = 'arn:aws:sagemaker:us-east-2:786796469737:model-package/numerical-drift-v1'

# %%
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_session = sage.Session()

# %%
#Define predictor wrapper class
def predict_wrapper(endpoint, session):
    return sage.RealTimePredictor(endpoint, session,content_type=content_type)
#create a deployable model from the model package.
model = ModelPackage(role=role,
                    model_package_arn=model_package_arn,
                    sagemaker_session=sagemaker_session,
                    predictor_cls=predict_wrapper)

# %%
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)

# %% [markdown]
# ###  1. Invoking endpoint result through CLI command

# %%
file_name="prediction.csv"

# %%
# !aws sagemaker-runtime invoke-endpoint --endpoint-name $model_name --body fileb://$file_name --content-type 'text/csv' --region us-east-2 result1.csv
# Out:
# {
#     "ContentType": "text/csv; charset=utf-8",
#     "InvokedProductionVariant": "AllTraffic"
# }

# %%
df = pd.read_csv("result1.csv")
df=df.drop(columns='Unnamed: 0')
df.head(20)
# Out:
#         date  day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0   0.000177  6    0.659574  0.072745  0.287266   0.003467  0.422915
# 1   0.000221  7    0.319149  0.047256  0.180452   0.003467  0.422915
# 2   0.000221  7    1.000000  0.047106  0.293663   0.003467  0.422915
# 3   0.000354  3    0.659574  0.045214  0.450164   0.003467  0.422915
# 4   0.004248  1    1.000000  0.076108  0.475156   0.003467  0.422915
# 5   0.004292  2    0.659574  0.046806  0.505653   0.003467  0.422915
# 6   0.004336  3    1.000000  0.045394  0.506397   0.003467  0.422915
# 7   0.005044  5    1.000000  0.047886  0.514281   0.003467  0.422915
# 8   0.005133  7    0.319149  0.068362  0.231627   0.003467  0.422915
# 9   0.009646  4    0.319149  0.045605  0.631508   0.003467  0.422915
# 10  0.013053  5    1.000000  0.048247  0.534216   0.003467  0.422915
# 11  0.013318  4    1.000000  0.081002  0.598483   0.003467  0.422915
# 12  0.013672  5    1.000000  0.051549  0.508331   0.003467  0.422915
# 13  0.022565  4    1.000000  0.057644  0.426807   0.003467  0.422915
# 14  0.022787  2    0.659574  0.084814  0.433502   0.003467  0.422915
# 15  0.023096  2    1.000000  0.101567  0.390955   0.003467  0.422915
# 16  0.030707  7    0.659574  0.083794  0.288158   0.003467  0.422915
# 17  0.030795  2    0.659574  0.111174  0.538976   0.003467  0.422915
# 18  0.031990  1    1.000000  0.086015  0.300208   0.003467  0.422915
# 19  0.424671  7    0.319149  0.074817  0.203957   0.003467  0.422915
#
#     transfer class predicted
# 0   0.414912  UP    UP
# 1   0.414912  DOWN  UP
# 2   0.414912  DOWN  UP
# 3   0.414912  DOWN  UP
# 4   0.414912  UP    UP
# 5   0.414912  DOWN  UP
# 6   0.414912  DOWN  UP
# 7   0.414912  DOWN  UP
# 8   0.414912  UP    UP
# 9   0.414912  DOWN  UP
# 10  0.414912  UP    UP
# 11  0.414912  UP    UP
# 12  0.414912  UP    UP
# 13  0.414912  DOWN  UP
# 14  0.414912  DOWN  UP
# 15  0.414912  UP    UP
# 16  0.414912  UP    UP
# 17  0.414912  UP    UP
# 18  0.414912  UP    UP
# 19  0.414912  UP    UP

# %% [markdown]
# ### 2. Invoking endpoint result through python code

# %%
f = open('./prediction.csv', mode='r')
data=f.read()
prediction = predictor.predict(data)

# %%
from io import StringIO

s=str(prediction,'utf-8')
data = StringIO(s) 
df=pd.read_csv(data)
df=df.drop(columns='Unnamed: 0')
df
# Out:
#         date  day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0   0.000177  6    0.659574  0.072745  0.287266   0.003467  0.422915
# 1   0.000221  7    0.319149  0.047256  0.180452   0.003467  0.422915
# 2   0.000221  7    1.000000  0.047106  0.293663   0.003467  0.422915
# 3   0.000354  3    0.659574  0.045214  0.450164   0.003467  0.422915
# 4   0.004248  1    1.000000  0.076108  0.475156   0.003467  0.422915
# 5   0.004292  2    0.659574  0.046806  0.505653   0.003467  0.422915
# 6   0.004336  3    1.000000  0.045394  0.506397   0.003467  0.422915
# 7   0.005044  5    1.000000  0.047886  0.514281   0.003467  0.422915
# 8   0.005133  7    0.319149  0.068362  0.231627   0.003467  0.422915
# 9   0.009646  4    0.319149  0.045605  0.631508   0.003467  0.422915
# 10  0.013053  5    1.000000  0.048247  0.534216   0.003467  0.422915
# 11  0.013318  4    1.000000  0.081002  0.598483   0.003467  0.422915
# 12  0.013672  5    1.000000  0.051549  0.508331   0.003467  0.422915
# 13  0.022565  4    1.000000  0.057644  0.426807   0.003467  0.422915
# 14  0.022787  2    0.659574  0.084814  0.433502   0.003467  0.422915
# 15  0.023096  2    1.000000  0.101567  0.390955   0.003467  0.422915
# 16  0.030707  7    0.659574  0.083794  0.288158   0.003467  0.422915
# 17  0.030795  2    0.659574  0.111174  0.538976   0.003467  0.422915
# 18  0.031990  1    1.000000  0.086015  0.300208   0.003467  0.422915
# 19  0.424671  7    0.319149  0.074817  0.203957   0.003467  0.422915
# 20  0.434450  3    0.319149  0.058094  0.485272   0.003467  0.422915
# 21  0.434538  5    0.319149  0.044314  0.249331   0.003467  0.422915
# 22  0.451971  3    0.659574  0.033626  0.560994   0.002277  0.546349
# 23  0.452060  5    0.659574  0.033145  0.501041   0.002212  0.555153
# 24  0.455688  4    0.319149  0.092110  0.695031   0.006352  0.591921
# 25  0.464404  6    0.319149  0.037769  0.396906   0.002607  0.431901
# 26  0.464581  3    1.000000  0.076048  0.461619   0.005249  0.399534
# 27  0.477988  2    1.000000  0.038009  0.450759   0.002628  0.385552
# 28  0.482412  3    0.659574  0.033746  0.456858   0.002360  0.480321
# 29  0.898633  2    1.000000  0.078149  0.559357   0.005154  0.496634
# 30  0.902703  4    0.659574  0.037829  0.465933   0.002580  0.507509
# 31  0.902836  7    1.000000  0.048427  0.348706   0.003232  0.404713
# 32  0.907703  5    0.319149  0.051339  0.466677   0.003484  0.539617
#
#     transfer class predicted
# 0   0.414912  UP    UP
# 1   0.414912  DOWN  UP
# 2   0.414912  DOWN  UP
# 3   0.414912  DOWN  UP
# 4   0.414912  UP    UP
# 5   0.414912  DOWN  UP
# 6   0.414912  DOWN  UP
# 7   0.414912  DOWN  UP
# 8   0.414912  UP    UP
# 9   0.414912  DOWN  UP
# 10  0.414912  UP    UP
# 11  0.414912  UP    UP
# 12  0.414912  UP    UP
# 13  0.414912  DOWN  UP
# 14  0.414912  DOWN  UP
# 15  0.414912  UP    UP
# 16  0.414912  UP    UP
# 17  0.414912  UP    UP
# 18  0.414912  UP    UP
# 19  0.414912  UP    UP
# 20  0.414912  UP    UP
# 21  0.414912  DOWN  UP
# 22  0.385088  DOWN  UP
# 23  0.424561  DOWN  UP
# 24  0.492982  UP    UP
# 25  0.248246  UP    UP
# 26  0.351316  UP    UP
# 27  0.292982  DOWN  UP
# 28  0.217105  DOWN  UP
# 29  0.610088  DOWN  UP
# 30  0.390789  DOWN  UP
# 31  0.535526  DOWN  UP
# 32  0.397368  UP    UP

# %%
predictor.delete_endpoint()
