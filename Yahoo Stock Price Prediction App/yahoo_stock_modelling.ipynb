# %%
import os
os.system("pip install convertdate==2.2.1 pystan==2.19.1.1 fbprophet==0.6")
os.system("pip install slack")
os.system("pip install slackclient")
os.system("pip install yfinance")
os.system("pip install yahoofinancials")
os.system("pip install statsmodels")
os.system("pip install sklearn")
# Out:
# Collecting convertdate==2.2.1
#   Downloading convertdate-2.2.1-py2.py3-none-any.whl (43 kB)
# Requirement already satisfied: pystan==2.19.1.1 in /opt/conda/lib/python3.8/site-packages (2.19.1.1)
# Collecting fbprophet==0.6
#   Using cached fbprophet-0.6.tar.gz (54 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pymeeus<=1,>=0.3.6 in /opt/conda/lib/python3.8/site-packages (from convertdate==2.2.1) (0.5.11)
# Requirement already satisfied: pytz>=2014.10 in /opt/conda/lib/python3.8/site-packages (from convertdate==2.2.1) (2021.3)
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.8/site-packages (from pystan==2.19.1.1) (1.21.4)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /opt/conda/lib/python3.8/site-packages (from pystan==2.19.1.1) (0.29.26)
# Requirement already satisfied: cmdstanpy==0.4 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (0.4.0)
# Requirement already satisfied: pandas>=0.23.4 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (1.3.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (3.5.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (0.0.9)
# Requirement already satisfied: holidays>=0.9.5 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (0.12)
# Requirement already satisfied: setuptools-git>=1.2 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (1.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in /opt/conda/lib/python3.8/site-packages (from fbprophet==0.6) (2.8.2)
# Requirement already satisfied: korean-lunar-calendar in /opt/conda/lib/python3.8/site-packages (from holidays>=0.9.5->fbprophet==0.6) (0.2.1)
# Requirement already satisfied: hijri-converter in /opt/conda/lib/python3.8/site-packages (from holidays>=0.9.5->fbprophet==0.6) (2.2.2)
# Collecting holidays>=0.9.5
#   Downloading holidays-0.11.3.1-py3-none-any.whl (155 kB)
#   Downloading holidays-0.11.2-py3-none-any.whl (142 kB)
#   Downloading holidays-0.11.1-py3-none-any.whl (133 kB)
#   Downloading holidays-0.10.5.2.tar.gz (121 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from holidays>=0.9.5->fbprophet==0.6) (1.15.0)
#   Downloading holidays-0.10.4.tar.gz (120 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
#   Downloading holidays-0.10.3.tar.gz (114 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ephem>=3.7.5.3 in /opt/conda/lib/python3.8/site-packages (from LunarCalendar>=0.0.9->fbprophet==0.6) (4.1.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (21.2)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib>=2.0.0->fbprophet==0.6) (4.28.5)
# Building wheels for collected packages: fbprophet, holidays
#   Building wheel for fbprophet (setup.py): started
#   Building wheel for fbprophet (setup.py): still running...
#   Building wheel for fbprophet (setup.py): finished with status 'error'
#   Running setup.py clean for fbprophet
#   ERROR: Command errored out with exit status 1:
#    command: /opt/conda/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-6mar2bh5
#        cwd: /tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/
#   Complete output (10 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib
#   creating build/lib/fbprophet
#   creating build/lib/fbprophet/stan_model
#   Importing plotly failed. Interactive plots will not work.
#   INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_888a84912910fa0a45b9d614b75bb8a8 NOW.
#   error: command 'gcc' failed with exit status 4
#   ----------------------------------------
#   ERROR: Failed building wheel for fbprophet
#   Building wheel for holidays (setup.py): started
#   Building wheel for holidays (setup.py): finished with status 'done'
#   Created wheel for holidays: filename=holidays-0.10.3-py3-none-any.whl size=115865 sha256=2979672b4a3a4b111eea46afb309a85dd5c50261246a7bcf64249177515186ea
#   Stored in directory: /home/katonic/.cache/pip/wheels/a2/97/85/fd3fe9e0f96120582caa3470bde6652f826b4e5842e3cce65c
# Successfully built holidays
# Failed to build fbprophet
# Installing collected packages: convertdate, holidays, fbprophet
#   Attempting uninstall: convertdate
#     Found existing installation: convertdate 2.3.2
#     Uninstalling convertdate-2.3.2:
#       Successfully uninstalled convertdate-2.3.2
#   Attempting uninstall: holidays
#     Found existing installation: holidays 0.12
#     Uninstalling holidays-0.12:
#       Successfully uninstalled holidays-0.12
#     Running setup.py install for fbprophet: started
#     Running setup.py install for fbprophet: still running...
#     ERROR: Command errored out with exit status 1:
#      command: /opt/conda/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-7ak6z_et/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/include/python3.8/fbprophet
#          cwd: /tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/
#     Complete output (10 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib
#     creating build/lib/fbprophet
#     creating build/lib/fbprophet/stan_model
#     Importing plotly failed. Interactive plots will not work.
#     INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_888a84912910fa0a45b9d614b75bb8a8 NOW.
#     error: command 'gcc' failed with exit status 4
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /opt/conda/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"'; __file__='"'"'/tmp/pip-install-wnk5434q/fbprophet_0966e45319aa4566862819eb3aa6f8a7/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-7ak6z_et/install-record.txt --single-version-externally-managed --compile --install-headers /opt/conda/include/python3.8/fbprophet Check the logs for full command output.
#     Running setup.py install for fbprophet: finished with status 'error'
# Collecting slack
#   Downloading slack-0.0.2.tar.gz (2.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: slack
#   Building wheel for slack (setup.py): started
#   Building wheel for slack (setup.py): finished with status 'done'
#   Created wheel for slack: filename=slack-0.0.2-py3-none-any.whl size=2527 sha256=5eb8696759c0ac6077ed9256428472ab1090e5f54d1d9b2b93882b079cfec6e9
#   Stored in directory: /home/katonic/.cache/pip/wheels/2e/0e/98/3777a34a03cb4f6a1e5d8aa1f1dd1f1d83760c623950cf53bf
# Successfully built slack
# Installing collected packages: slack
# Successfully installed slack-0.0.2
# Collecting slackclient
#   Downloading slackclient-2.9.3-py2.py3-none-any.whl (96 kB)
# Collecting aiohttp<4.0.0,>3.5.2
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (210 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (187 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>3.5.2->slackclient) (20.3.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (308 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /opt/conda/lib/python3.8/site-packages (from aiohttp<4.0.0,>3.5.2->slackclient) (2.0.4)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.8/site-packages (from yarl<2.0,>=1.0->aiohttp<4.0.0,>3.5.2->slackclient) (3.2)
# Installing collected packages: multidict, frozenlist, yarl, async-timeout, aiosignal, aiohttp, slackclient
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 frozenlist-1.2.0 multidict-5.2.0 slackclient-2.9.3 yarl-1.7.2
# Collecting yfinance
#   Downloading yfinance-0.1.69-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.24 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.3.5)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.7.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.9 MB)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.10.tar.gz (8.2 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.26 in /opt/conda/lib/python3.8/site-packages (from yfinance) (2.26.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.8/site-packages (from yfinance) (1.21.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.24->yfinance) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.26->yfinance) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.26->yfinance) (3.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (setup.py): started
#   Building wheel for multitasking (setup.py): finished with status 'done'
#   Created wheel for multitasking: filename=multitasking-0.0.10-py3-none-any.whl size=8500 sha256=383d383e5da6e64913960e9a5bad38ed8391bfaed0acfa27d727c5e97dd62308
#   Stored in directory: /home/katonic/.cache/pip/wheels/21/c9/66/b41c847de65c7985db52ec21d59996841598b8b0e93f2b9500
# Successfully built multitasking
# Installing collected packages: multitasking, lxml, yfinance
# Successfully installed lxml-4.7.1 multitasking-0.0.10 yfinance-0.1.69
# Collecting yahoofinancials
#   Downloading yahoofinancials-1.6.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.10.0-py3-none-any.whl (97 kB)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.8/site-packages (from yahoofinancials) (2021.3)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.3.1-py3-none-any.whl (37 kB)
# Building wheels for collected packages: yahoofinancials
#   Building wheel for yahoofinancials (setup.py): started
#   Building wheel for yahoofinancials (setup.py): finished with status 'done'
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-py3-none-any.whl size=15190 sha256=48031f07c1a8f5de7fdcf5cfa5eb27a4d8049d5898caddad3da685144fa70030
#   Stored in directory: /home/katonic/.cache/pip/wheels/6a/90/0c/08c7ac2ce60b9ac91529417d471e59244f9f96848c86f14809
# Successfully built yahoofinancials
# Installing collected packages: soupsieve, beautifulsoup4, yahoofinancials
# Successfully installed beautifulsoup4-4.10.0 soupsieve-2.3.1 yahoofinancials-1.6
# Collecting statsmodels
#   Downloading statsmodels-0.13.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
# Collecting scipy>=1.3
#   Downloading scipy-1.7.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.3 MB)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.8/site-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.8/site-packages (from statsmodels) (1.21.4)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.2-py2.py3-none-any.whl (233 kB)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Installing collected packages: scipy, patsy, statsmodels
# Successfully installed patsy-0.5.2 scipy-1.7.3 statsmodels-0.13.1
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.0.0-py3-none-any.whl (14 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /opt/conda/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.21.4)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=4992e63a93073388e623238611a354de15335c39195280a5de86b726ee802457
#   Stored in directory: /home/katonic/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.0 scikit-learn-1.0.2 sklearn-0.0 threadpoolctl-3.0.0
# 0

# %%
#!pip install Cython>=0.22
#!pip install cmdstanpy==0.9.77
#!pip install pystan~=2.19.1.1
#!pip install numpy>=1.15.4
#!pip install pandas>=1.0.4
#!pip install matplotlib>=2.0.0
#!pip install LunarCalendar>=0.0.9
#!pip install convertdate>=2.1.2
#!pip install holidays>=0.11.3.1
#!pip install setuptools>=42
#!pip install setuptools-git>=1.2
#!pip install python-dateutil>=2.8.0
#!pip install tqdm>=4.36.1
#!pip install wheel>=0.37.0
# Out:
# Collecting cmdstanpy==0.9.77
#   Downloading cmdstanpy-0.9.77-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 697 kB/s
# Collecting pandas
#   Downloading pandas-1.3.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 4.5 MB/s            3�█████▏                | 5.5 MB 4.5 MB/s eta 0:00:02��█      | 9.3 MB 4.5 MB/s eta 0:00:01
# Collecting ujson
#   Downloading ujson-5.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44 kB)
#      |████████████████████████████████| 44 kB 481 kB/s
# Requirement already satisfied: numpy!=1.19.4,>=1.15 in /opt/conda/lib/python3.8/site-packages (from cmdstanpy==0.9.77) (1.21.4)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas->cmdstanpy==0.9.77) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas->cmdstanpy==0.9.77) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas->cmdstanpy==0.9.77) (1.15.0)
# Installing collected packages: ujson, pandas, cmdstanpy
# Successfully installed cmdstanpy-0.9.77 pandas-1.3.5 ujson-5.1.0
# Collecting pystan~=2.19.1.1
#   Downloading pystan-2.19.1.1-cp38-cp38-manylinux1_x86_64.whl (62.6 MB)
#      |████████████████████████████████| 62.6 MB 73 kB/s              █                              | 3.9 MB 2.7 MB/s eta 0:00:22 8.0 MB 2.7 MB/s eta 0:00:20��█████▌                         | 12.6 MB 2.7 MB/s eta 0:00:19  | 15.2 MB 2.7 MB/s eta 0:00:18                 | 18.1 MB 2.7 MB/s eta 0:00:17:00:16��█████████▌                 | 28.4 MB 2.7 MB/s eta 0:00:131.8 MB 2.7 MB/s eta 0:00:12eta 0:00:10��████████▉            | 38.8 MB 2.7 MB/s eta 0:00:09    | 42.7 MB 2.7 MB/s eta 0:00:08    | 45.4 MB 2.7 MB/s eta 0:00:07MB 2.7 MB/s eta 0:00:05████████████████▋     | 52.0 MB 2.7 MB/s eta 0:00:043��█████████████████████████▉ | 60.2 MB 68.0 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.7 in /opt/conda/lib/python3.8/site-packages (from pystan~=2.19.1.1) (1.21.4)
# Requirement already satisfied: Cython!=0.25.1,>=0.22 in /opt/conda/lib/python3.8/site-packages (from pystan~=2.19.1.1) (0.29.26)
# Installing collected packages: pystan
# Successfully installed pystan-2.19.1.1

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
plt.style.use('fivethirtyeight')

import yfinance as yf
from yahoofinancials import YahooFinancials
import statistics
from statistics import stdev

from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from numpy import log
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from fbprophet import Prophet
from datetime import date
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from matplotlib import pyplot

from typing import  List
from datetime import datetime
from io import StringIO
import joblib
from minio import Minio
from subprocess import run, Popen, PIPE

import joblib

# %%
period='2y'
ticker = 'MSFT' #AAPL
path = "/kfs_private/yahoo_stock/"

# %%
df = yf.download(ticker, period=period).reset_index()
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2020-01-15  162.619995  163.940002  162.570007  163.179993  160.127213
# 1 2020-01-16  164.350006  166.240005  164.029999  166.169998  163.061295
# 2 2020-01-17  167.419998  167.470001  165.429993  167.100006  163.973907
# 3 2020-01-21  166.679993  168.190002  166.429993  166.500000  163.385117
# 4 2020-01-22  167.399994  167.490005  165.679993  165.699997  162.600067
#
#      Volume
# 0  21417900
# 1  23865400
# 2  34371700
# 3  29517200
# 4  24138800

# %%
df.shape
# Out:
# (506, 7)

# %%
len(df['Date'].unique())
# Out:
# 506

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       506 non-null    datetime64[ns]
#  1   Open       506 non-null    float64
#  2   High       506 non-null    float64
#  3   Low        506 non-null    float64
#  4   Close      506 non-null    float64
#  5   Adj Close  506 non-null    float64
#  6   Volume     506 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 27.8 KB

# %%
df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.Date=pd.to_datetime(df['Date'])

# %%
df.Date.min(),df.Date.max()
# Out:
# (Timestamp('2020-01-15 00:00:00'), Timestamp('2022-01-14 00:00:00'))

# %%
df.Date.max()-df.Date.min()
# Out:
# Timedelta('730 days 00:00:00')

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-15  162.619995  163.940002  162.570007  163.179993  160.127213
# 2020-01-16  164.350006  166.240005  164.029999  166.169998  163.061295
# 2020-01-17  167.419998  167.470001  165.429993  167.100006  163.973907
# 2020-01-21  166.679993  168.190002  166.429993  166.500000  163.385117
# 2020-01-22  167.399994  167.490005  165.679993  165.699997  162.600067
#
#               Volume
# Date
# 2020-01-15  21417900
# 2020-01-16  23865400
# 2020-01-17  34371700
# 2020-01-21  29517200
# 2020-01-22  24138800

# %%
df[['High','Low','Open','Close']].plot(figsize = (15, 5), alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.High.hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
sh = int(np.round(df.shape[0]/10,0))
sh
# Out:
# 51

# %%
mean=[]
std=[]
    
for i in range(0,10):
    mean.append(df['High'].iloc[(i*sh):(i*sh)+sh].mean())
    std.append(stdev(df['High'].iloc[(i*sh):(i*sh)+sh]))

# %%
pd.concat([pd.DataFrame(mean,columns=['mean']),pd.DataFrame(std,columns=['std'])], axis=1)
# Out:
#          mean        std
# 0  168.597059  13.240062
# 1  178.759804   9.409284
# 2  207.457059   7.025345
# 3  214.885882   7.878853
# 4  218.530196   4.090333
# 5  238.080392   5.063910
# 6  253.798824   5.354370
# 7  283.702351  11.936768
# 8  306.253922  13.941312
# 9  334.216811   9.000315

# %%
decompose_add=seasonal_decompose(df['High'], model='additive', period=12)
plt.figure(figsize=(15,15))
plt.subplot(411)
plt.plot(df['High'], label='Original TS')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(decompose_add.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(decompose_add.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(decompose_add.resid, label='Residual')
plt.legend(loc='best')

# %%
decompose_mul=seasonal_decompose(df['High'], model='multiplicative', period=12)
plt.figure(figsize=(15,15))
plt.subplot(411)
plt.plot(df['High'], label='Original TS')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(decompose_mul.trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(decompose_mul.seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(decompose_mul.resid, label='Residual')
plt.legend(loc='best')

# %%
plt.rc("figure", figsize=(10,5))
plot_acf(df['High'])
print()

# %%
plt.rc("figure", figsize=(10,5))
plot_pacf(df['High'])
print()
# Out:
# /opt/conda/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
result = adfuller(df['High'])
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -0.772276
# p-value: 0.827131
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
result = adfuller(log(df['High']))
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -1.010626
# p-value: 0.749369
# Critical Values:
# 	1%: -3.443
# 	5%: -2.867
# 	10%: -2.570

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-15  162.619995  163.940002  162.570007  163.179993  160.127213
# 2020-01-16  164.350006  166.240005  164.029999  166.169998  163.061295
# 2020-01-17  167.419998  167.470001  165.429993  167.100006  163.973907
# 2020-01-21  166.679993  168.190002  166.429993  166.500000  163.385117
# 2020-01-22  167.399994  167.490005  165.679993  165.699997  162.600067
# ...                ...         ...         ...         ...         ...
# 2022-01-10  309.489990  314.720001  304.690002  314.269989  314.269989
# 2022-01-11  313.380005  316.609985  309.890015  314.980011  314.980011
# 2022-01-12  319.670013  323.410004  317.079987  318.269989  318.269989
# 2022-01-13  320.470001  320.880005  304.000000  304.799988  304.799988
# 2022-01-14  304.250000  310.820007  303.750000  310.200012  310.200012
#
#               Volume
# Date
# 2020-01-15  21417900
# 2020-01-16  23865400
# 2020-01-17  34371700
# 2020-01-21  29517200
# 2020-01-22  24138800
# ...              ...
# 2022-01-10  44289500
# 2022-01-11  29386800
# 2022-01-12  34372200
# 2022-01-13  45366000
# 2022-01-14  39823500
#
# [506 rows x 6 columns]

# %%
new_df=df['High'].iloc[:-4]

# %%
df=df.reset_index()[['Date','High']].rename({'Date':'ds','High':'y'},axis='columns')

# %%
train=df[df['ds'] <= (df['ds'].max() - pd.DateOffset(months=3))]
test=df[df['ds'] > (df['ds'].max() - pd.DateOffset(months=3))]

# %%
MODEL_NAME = "yahoo_stock_model_"+ticker

# %%
model=Prophet()
model.fit(train)

test_pred = model.predict(test[['ds']])

print("r2_score : ", r2_score(test['y'],test_pred['yhat']))
print("mean_absolute_error : ", mean_absolute_error(test['y'],test_pred['yhat']))

print("root_mean_squared_error : ", np.sqrt(mean_squared_error(test['y'],test_pred['yhat'])))

# %%
joblib.dump(model,path+MODEL_NAME+".joblib")

# %%
model = joblib.load(path+MODEL_NAME+".joblib")
plt.plot(test['y'].values, label='Actual')
plt.plot(test_pred['yhat'].values, label='Predicted')
plt.legend()
plt.show()

# %%
model.plot(test_pred)
plt.show()
